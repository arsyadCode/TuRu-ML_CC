# %% [markdown]
# # Setting Up Kaggle

# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-bb306067-14b4-4ff6-af13-2fe70b865c4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb306067-14b4-4ff6-af13-2fe70b865c4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kmarsyad","key":"0b2fab08fb1915b97629ea87647e49a5"}'}

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d mrgeislinger/asl-rgb-depth-fingerspelling-spelling-it-out
# Out:
# Downloading asl-rgb-depth-fingerspelling-spelling-it-out.zip to /content
# 100% 2.10G/2.11G [00:16<00:00, 160MB/s]
# 100% 2.11G/2.11G [00:16<00:00, 139MB/s]

# %%
! kaggle datasets download -d keras/vgg19
# Out:
# Downloading vgg19.zip to /content
#  95% 553M/580M [00:04<00:00, 153MB/s]
# 100% 580M/580M [00:05<00:00, 121MB/s]

# %%
! unzip /content/asl-rgb-depth-fingerspelling-spelling-it-out.zip -d /input

! unzip /content/vgg19.zip -d /input
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /input/dataset5/E/u/color_20_0236.png
#   inflating: /input/dataset5/E/u/color_20_0237.png
#   inflating: /input/dataset5/E/u/color_20_0238.png
#   inflating: /input/dataset5/E/u/color_20_0239.png
#   inflating: /input/dataset5/E/u/color_20_0240.png
#   inflating: /input/dataset5/E/u/color_20_0241.png
#   inflating: /input/dataset5/E/u/color_20_0242.png
#   inflating: /input/dataset5/E/u/color_20_0243.png
#   inflating: /input/dataset5/E/u/color_20_0244.png
#   inflating: /input/dataset5/E/u/color_20_0245.png
#   inflating: /input/dataset5/E/u/color_20_0246.png
#   inflating: /input/dataset5/E/u/color_20_0247.png
#   inflating: /input/dataset5/E/u/color_20_0248.png
#   inflating: /input/dataset5/E/u/color_20_0249.png
#   inflating: /input/dataset5/E/u/color_20_0250.png
#   inflating: /input/dataset5/E/u/color_20_0251.png
#   inflating: /input/dataset5/E/u/color_20_0252.png
#   inflating: /input/dataset5/E/u/color_20_0253.png
#   inflating: /input/dataset5/E/u/color_20_0254.png
#   inflating: /input/dataset5/E/u/color_20_0255.png
#   inflating: /input/dataset5/E/u/color_20_0256.png
#   inflating: /input/dataset5/E/u/color_20_0257.png
#   inflating: /input/dataset5/E/u/color_20_0258.png
#   inflating: /input/dataset5/E/u/color_20_0259.png
#   inflating: /input/dataset5/E/u/color_20_0260.png
#   inflating: /input/dataset5/E/u/color_20_0261.png
#   inflating: /input/dataset5/E/u/color_20_0262.png
#   inflating: /input/dataset5/E/u/color_20_0263.png
#   inflating: /input/dataset5/E/u/color_20_0264.png
#   inflating: /input/dataset5/E/u/color_20_0265.png
#   inflating: /input/dataset5/E/u/color_20_0266.png
#   inflating: /input/dataset5/E/u/color_20_0267.png
#   inflating: /input/dataset5/E/u/color_20_0268.png
#   inflating: /input/dataset5/E/u/color_20_0269.png
#   inflating: /input/dataset5/E/u/color_20_0270.png
#   inflating: /input/dataset5/E/u/color_20_0271.png
#   inflating: /input/dataset5/E/u/color_20_0272.png
#   inflating: /input/dataset5/E/u/color_20_0273.png
#   inflating: /input/dataset5/E/u/color_20_0274.png
#   inflating: /input/dataset5/E/u/color_20_0275.png
#   inflating: /input/dataset5/E/u/color_20_0276.png
#   inflating: /input/dataset5/E/u/color_20_0277.png
#   inflating: /input/dataset5/E/u/color_20_0278.png
#   inflating: /input/dataset5/E/u/color_20_0279.png
#   inflating: /input/dataset5/E/u/color_20_0280.png
#   inflating: /input/dataset5/E/u/color_20_0281.png
#   inflating: /input/dataset5/E/u/color_20_0282.png
#   inflating: /input/dataset5/E/u/color_20_0283.png
#   inflating: /input/dataset5/E/u/color_20_0284.png
#   inflating: /input/dataset5/E/u/color_20_0285.png
#   inflating: /input/dataset5/E/u/color_20_0286.png
#   inflating: /input/dataset5/E/u/color_20_0287.png
#   inflating: /input/dataset5/E/u/color_20_0288.png
#   inflating: /input/dataset5/E/u/color_20_0289.png
#   inflating: /input/dataset5/E/u/color_20_0290.png
#   inflating: /input/dataset5/E/u/color_20_0291.png
#   inflating: /input/dataset5/E/u/color_20_0292.png
#   inflating: /input/dataset5/E/u/color_20_0293.png
#   inflating: /input/dataset5/E/u/color_20_0294.png
#   inflating: /input/dataset5/E/u/color_20_0295.png
#   inflating: /input/dataset5/E/u/color_20_0296.png
#   inflating: /input/dataset5/E/u/color_20_0297.png
#   inflating: /input/dataset5/E/u/color_20_0298.png
#   inflating: /input/dataset5/E/u/color_20_0299.png
#   inflating: /input/dataset5/E/u/color_20_0300.png
#   inflating: /input/dataset5/E/u/color_20_0301.png
#   inflating: /input/dataset5/E/u/color_20_0302.png
#   inflating: /input/dataset5/E/u/color_20_0303.png
#   inflating: /input/dataset5/E/u/color_20_0304.png
#   inflating: /input/dataset5/E/u/color_20_0305.png
#   inflating: /input/dataset5/E/u/color_20_0306.png
#   inflating: /input/dataset5/E/u/color_20_0307.png
#   inflating: /input/dataset5/E/u/color_20_0308.png
#   inflating: /input/dataset5/E/u/color_20_0309.png
#   inflating: /input/dataset5/E/u/color_20_0310.png
#   inflating: /input/dataset5/E/u/color_20_0311.png
#   inflating: /input/dataset5/E/u/color_20_0312.png
#   inflating: /input/dataset5/E/u/color_20_0313.png
#   inflating: /input/dataset5/E/u/color_20_0314.png
#   inflating: /input/dataset5/E/u/color_20_0315.png
#   inflating: /input/dataset5/E/u/color_20_0316.png
#   inflating: /input/dataset5/E/u/color_20_0317.png
#   inflating: /input/dataset5/E/u/color_20_0318.png
#   inflating: /input/dataset5/E/u/color_20_0319.png
#   inflating: /input/dataset5/E/u/color_20_0320.png
#   inflating: /input/dataset5/E/u/color_20_0321.png
#   inflating: /input/dataset5/E/u/color_20_0322.png
#   inflating: /input/dataset5/E/u/color_20_0323.png
#   inflating: /input/dataset5/E/u/color_20_0324.png
#   inflating: /input/dataset5/E/u/color_20_0325.png
#   inflating: /input/dataset5/E/u/color_20_0326.png
#   inflating: /input/dataset5/E/u/color_20_0327.png
#   inflating: /input/dataset5/E/u/color_20_0328.png
#   inflating: /input/dataset5/E/u/color_20_0329.png
#   inflating: /input/dataset5/E/u/color_20_0330.png
#   inflating: /input/dataset5/E/u/color_20_0331.png
#   inflating: /input/dataset5/E/u/color_20_0332.png
#   inflating: /input/dataset5/E/u/color_20_0333.png
#   inflating: /input/dataset5/E/u/color_20_0334.png
#   inflating: /input/dataset5/E/u/color_20_0335.png
#   inflating: /input/dataset5/E/u/color_20_0336.png
#   inflating: /input/dataset5/E/u/color_20_0337.png
#   inflating: /input/dataset5/E/u/color_20_0338.png
#   inflating: /input/dataset5/E/u/color_20_0339.png
#   inflating: /input/dataset5/E/u/color_20_0340.png
#   inflating: /input/dataset5/E/u/color_20_0341.png
#   inflating: /input/dataset5/E/u/color_20_0342.png
#   inflating: /input/dataset5/E/u/color_20_0343.png
#   inflating: /input/dataset5/E/u/color_20_0344.png
#   inflating: /input/dataset5/E/u/color_20_0345.png
#   inflating: /input/dataset5/E/u/color_20_0346.png
#   inflating: /input/dataset5/E/u/color_20_0347.png
#   inflating: /input/dataset5/E/u/color_20_0348.png
#   inflating: /input/dataset5/E/u/color_20_0349.png
#   inflating: /input/dataset5/E/u/color_20_0350.png
#   inflating: /input/dataset5/E/u/color_20_0351.png
#   inflating: /input/dataset5/E/u/color_20_0352.png
#   inflating: /input/dataset5/E/u/color_20_0353.png
#   inflating: /input/dataset5/E/u/color_20_0354.png
#   inflating: /input/dataset5/E/u/color_20_0355.png
#   inflating: /input/dataset5/E/u/color_20_0356.png
#   inflating: /input/dataset5/E/u/color_20_0357.png
#   inflating: /input/dataset5/E/u/color_20_0358.png
#   inflating: /input/dataset5/E/u/color_20_0359.png
#   inflating: /input/dataset5/E/u/color_20_0360.png
#   inflating: /input/dataset5/E/u/color_20_0361.png
#   inflating: /input/dataset5/E/u/color_20_0362.png
#   inflating: /input/dataset5/E/u/color_20_0363.png
#   inflating: /input/dataset5/E/u/color_20_0364.png
#   inflating: /input/dataset5/E/u/color_20_0365.png
#   inflating: /input/dataset5/E/u/color_20_0366.png
#   inflating: /input/dataset5/E/u/color_20_0367.png
#   inflating: /input/dataset5/E/u/color_20_0368.png
#   inflating: /input/dataset5/E/u/color_20_0369.png
#   inflating: /input/dataset5/E/u/color_20_0370.png
#   inflating: /input/dataset5/E/u/color_20_0371.png
#   inflating: /input/dataset5/E/u/color_20_0372.png
#   inflating: /input/dataset5/E/u/color_20_0373.png
#   inflating: /input/dataset5/E/u/color_20_0374.png
#   inflating: /input/dataset5/E/u/color_20_0375.png
#   inflating: /input/dataset5/E/u/color_20_0376.png
#   inflating: /input/dataset5/E/u/color_20_0377.png
#   inflating: /input/dataset5/E/u/color_20_0378.png
#   inflating: /input/dataset5/E/u/color_20_0379.png
#   inflating: /input/dataset5/E/u/color_20_0380.png
#   inflating: /input/dataset5/E/u/color_20_0381.png
#   inflating: /input/dataset5/E/u/color_20_0382.png
#   inflating: /input/dataset5/E/u/color_20_0383.png
#   inflating: /input/dataset5/E/u/color_20_0384.png
#   inflating: /input/dataset5/E/u/color_20_0385.png
#   inflating: /input/dataset5/E/u/color_20_0386.png
#   inflating: /input/dataset5/E/u/color_20_0387.png
#   inflating: /input/dataset5/E/u/color_20_0388.png
#   inflating: /input/dataset5/E/u/color_20_0389.png
#   inflating: /input/dataset5/E/u/color_20_0390.png
#   inflating: /input/dataset5/E/u/color_20_0391.png
#   inflating: /input/dataset5/E/u/color_20_0392.png
#   inflating: /input/dataset5/E/u/color_20_0393.png
#   inflating: /input/dataset5/E/u/color_20_0394.png
#   inflating: /input/dataset5/E/u/color_20_0395.png
#   inflating: /input/dataset5/E/u/color_20_0396.png
#   inflating: /input/dataset5/E/u/color_20_0397.png
#   inflating: /input/dataset5/E/u/color_20_0398.png
#   inflating: /input/dataset5/E/u/color_20_0399.png
#   inflating: /input/dataset5/E/u/color_20_0400.png
#   inflating: /input/dataset5/E/u/color_20_0401.png
#   inflating: /input/dataset5/E/u/color_20_0402.png
#   inflating: /input/dataset5/E/u/color_20_0403.png
#   inflating: /input/dataset5/E/u/color_20_0404.png
#   inflating: /input/dataset5/E/u/color_20_0405.png
#   inflating: /input/dataset5/E/u/color_20_0406.png
#   inflating: /input/dataset5/E/u/color_20_0407.png
#   inflating: /input/dataset5/E/u/color_20_0408.png
#   inflating: /input/dataset5/E/u/color_20_0409.png
#   inflating: /input/dataset5/E/u/color_20_0410.png
#   inflating: /input/dataset5/E/u/color_20_0411.png
#   inflating: /input/dataset5/E/u/color_20_0412.png
#   inflating: /input/dataset5/E/u/color_20_0413.png
#   inflating: /input/dataset5/E/u/color_20_0414.png
#   inflating: /input/dataset5/E/u/color_20_0415.png
#   inflating: /input/dataset5/E/u/color_20_0416.png
#   inflating: /input/dataset5/E/u/color_20_0417.png
#   inflating: /input/dataset5/E/u/color_20_0418.png
#   inflating: /input/dataset5/E/u/color_20_0419.png
#   inflating: /input/dataset5/E/u/color_20_0420.png
#   inflating: /input/dataset5/E/u/color_20_0421.png
#   inflating: /input/dataset5/E/u/color_20_0422.png
#   inflating: /input/dataset5/E/u/color_20_0423.png
#   inflating: /input/dataset5/E/u/color_20_0424.png
#   inflating: /input/dataset5/E/u/color_20_0425.png
#   inflating: /input/dataset5/E/u/color_20_0426.png
#   inflating: /input/dataset5/E/u/color_20_0427.png
#   inflating: /input/dataset5/E/u/color_20_0428.png
#   inflating: /input/dataset5/E/u/color_20_0429.png
#   inflating: /input/dataset5/E/u/color_20_0430.png
#   inflating: /input/dataset5/E/u/color_20_0431.png
#   inflating: /input/dataset5/E/u/color_20_0432.png
#   inflating: /input/dataset5/E/u/color_20_0433.png
#   inflating: /input/dataset5/E/u/color_20_0434.png
#   inflating: /input/dataset5/E/u/color_20_0435.png
#   inflating: /input/dataset5/E/u/color_20_0436.png
#   inflating: /input/dataset5/E/u/color_20_0437.png
#   inflating: /input/dataset5/E/u/color_20_0438.png
#   inflating: /input/dataset5/E/u/color_20_0439.png
#   inflating: /input/dataset5/E/u/color_20_0440.png
#   inflating: /input/dataset5/E/u/color_20_0441.png
#   inflating: /input/dataset5/E/u/color_20_0442.png
#   inflating: /input/dataset5/E/u/color_20_0443.png
#   inflating: /input/dataset5/E/u/color_20_0444.png
#   inflating: /input/dataset5/E/u/color_20_0445.png
#   inflating: /input/dataset5/E/u/color_20_0446.png
#   inflating: /input/dataset5/E/u/color_20_0447.png
#   inflating: /input/dataset5/E/u/color_20_0448.png
#   inflating: /input/dataset5/E/u/color_20_0449.png
#   inflating: /input/dataset5/E/u/color_20_0450.png
#   inflating: /input/dataset5/E/u/color_20_0451.png
#   inflating: /input/dataset5/E/u/color_20_0452.png
#   inflating: /input/dataset5/E/u/color_20_0453.png
#   inflating: /input/dataset5/E/u/color_20_0454.png
#   inflating: /input/dataset5/E/u/color_20_0455.png
#   inflating: /input/dataset5/E/u/color_20_0456.png
#   inflating: /input/dataset5/E/u/color_20_0457.png
#   inflating: /input/dataset5/E/u/color_20_0458.png
#   inflating: /input/dataset5/E/u/color_20_0459.png
#   inflating: /input/dataset5/E/u/color_20_0460.png
#   inflating: /input/dataset5/E/u/color_20_0461.png
#   inflating: /input/dataset5/E/u/color_20_0462.png
#   inflating: /input/dataset5/E/u/color_20_0463.png
#   inflating: /input/dataset5/E/u/color_20_0464.png
#   inflating: /input/dataset5/E/u/color_20_0465.png
#   inflating: /input/dataset5/E/u/color_20_0466.png
#   inflating: /input/dataset5/E/u/color_20_0467.png
#   inflating: /input/dataset5/E/u/color_20_0468.png
#   inflating: /input/dataset5/E/u/color_20_0469.png
#   inflating: /input/dataset5/E/u/color_20_0470.png
#   inflating: /input/dataset5/E/u/color_20_0471.png
#   inflating: /input/dataset5/E/u/color_20_0472.png
#   inflating: /input/dataset5/E/u/color_20_0473.png
#   inflating: /input/dataset5/E/u/color_20_0474.png
#   inflating: /input/dataset5/E/u/color_20_0475.png
#   inflating: /input/dataset5/E/u/color_20_0476.png
#   inflating: /input/dataset5/E/u/color_20_0477.png
#   inflating: /input/dataset5/E/u/color_20_0478.png
#   inflating: /input/dataset5/E/u/color_20_0479.png
#   inflating: /input/dataset5/E/u/color_20_0480.png
#   inflating: /input/dataset5/E/u/color_20_0481.png
#   inflating: /input/dataset5/E/u/color_20_0482.png
#   inflating: /input/dataset5/E/u/color_20_0483.png
#   inflating: /input/dataset5/E/u/color_20_0484.png
#   inflating: /input/dataset5/E/u/color_20_0485.png
#   inflating: /input/dataset5/E/u/color_20_0486.png
#   inflating: /input/dataset5/E/u/color_20_0487.png
#   inflating: /input/dataset5/E/u/color_20_0488.png
#   inflating: /input/dataset5/E/u/color_20_0489.png
#   inflating: /input/dataset5/E/u/color_20_0490.png
#   inflating: /input/dataset5/E/u/color_20_0491.png
#   inflating: /input/dataset5/E/u/color_20_0492.png
#   inflating: /input/dataset5/E/u/color_20_0493.png
#   inflating: /input/dataset5/E/u/color_20_0494.png
#   inflating: /input/dataset5/E/u/color_20_0495.png
#   inflating: /input/dataset5/E/u/color_20_0496.png
#   inflating: /input/dataset5/E/u/color_20_0497.png
#   inflating: /input/dataset5/E/u/color_20_0498.png
#   inflating: /input/dataset5/E/u/color_20_0499.png
#   inflating: /input/dataset5/E/u/color_20_0500.png
#   inflating: /input/dataset5/E/u/color_20_0501.png
#   inflating: /input/dataset5/E/u/color_20_0502.png
#   inflating: /input/dataset5/E/u/color_20_0503.png
#   inflating: /input/dataset5/E/u/color_20_0504.png
#   inflating: /input/dataset5/E/u/color_20_0505.png
#   inflating: /input/dataset5/E/u/color_20_0506.png
#   inflating: /input/dataset5/E/u/color_20_0507.png
#   inflating: /input/dataset5/E/u/color_20_0508.png
#   inflating: /input/dataset5/E/u/color_20_0509.png
#   inflating: /input/dataset5/E/u/color_20_0510.png
#   inflating: /input/dataset5/E/u/color_20_0511.png
#   inflating: /input/dataset5/E/u/color_20_0512.png
#   inflating: /input/dataset5/E/u/color_20_0513.png
#   inflating: /input/dataset5/E/u/color_20_0514.png
#   inflating: /input/dataset5/E/u/color_20_0515.png
#   inflating: /input/dataset5/E/u/color_20_0516.png
#   inflating: /input/dataset5/E/u/color_20_0517.png
#   inflating: /input/dataset5/E/u/color_20_0518.png
#   inflating: /input/dataset5/E/u/color_20_0519.png
#   inflating: /input/dataset5/E/u/color_20_0520.png
#   inflating: /input/dataset5/E/u/color_20_0521.png
#   inflating: /input/dataset5/E/u/color_20_0522.png
#   inflating: /input/dataset5/E/u/color_20_0523.png
#   inflating: /input/dataset5/E/u/color_20_0524.png
#   inflating: /input/dataset5/E/u/color_20_0525.png
#   inflating: /input/dataset5/E/u/color_20_0526.png
#   inflating: /input/dataset5/E/u/color_20_0527.png
#   inflating: /input/dataset5/E/u/color_20_0528.png
#   inflating: /input/dataset5/E/u/color_20_0529.png
#   inflating: /input/dataset5/E/u/color_20_0530.png
#   inflating: /input/dataset5/E/u/depth_20_0001.png
#   inflating: /input/dataset5/E/u/depth_20_0002.png
#   inflating: /input/dataset5/E/u/depth_20_0003.png
#   inflating: /input/dataset5/E/u/depth_20_0004.png
#   inflating: /input/dataset5/E/u/depth_20_0005.png
#   inflating: /input/dataset5/E/u/depth_20_0006.png
#   inflating: /input/dataset5/E/u/depth_20_0007.png
#   inflating: /input/dataset5/E/u/depth_20_0008.png
#   inflating: /input/dataset5/E/u/depth_20_0009.png
#   inflating: /input/dataset5/E/u/depth_20_0010.png
#   inflating: /input/dataset5/E/u/depth_20_0011.png
#   inflating: /input/dataset5/E/u/depth_20_0012.png
#   inflating: /input/dataset5/E/u/depth_20_0013.png
#   inflating: /input/dataset5/E/u/depth_20_0014.png
#   inflating: /input/dataset5/E/u/depth_20_0015.png
#   inflating: /input/dataset5/E/u/depth_20_0016.png
#   inflating: /input/dataset5/E/u/depth_20_0017.png
#   inflating: /input/dataset5/E/u/depth_20_0018.png
#   inflating: /input/dataset5/E/u/depth_20_0019.png
#   inflating: /input/dataset5/E/u/depth_20_0020.png
#   inflating: /input/dataset5/E/u/depth_20_0021.png
#   inflating: /input/dataset5/E/u/depth_20_0022.png
#   inflating: /input/dataset5/E/u/depth_20_0023.png
#   inflating: /input/dataset5/E/u/depth_20_0024.png
#   inflating: /input/dataset5/E/u/depth_20_0025.png
#   inflating: /input/dataset5/E/u/depth_20_0026.png
#   inflating: /input/dataset5/E/u/depth_20_0027.png
#   inflating: /input/dataset5/E/u/depth_20_0028.png
#   inflating: /input/dataset5/E/u/depth_20_0029.png
#   inflating: /input/dataset5/E/u/depth_20_0030.png
#   inflating: /input/dataset5/E/u/depth_20_0031.png
#   inflating: /input/dataset5/E/u/depth_20_0032.png
#   inflating: /input/dataset5/E/u/depth_20_0033.png
#   inflating: /input/dataset5/E/u/depth_20_0034.png
#   inflating: /input/dataset5/E/u/depth_20_0035.png
#   inflating: /input/dataset5/E/u/depth_20_0036.png
#   inflating: /input/dataset5/E/u/depth_20_0037.png
#   inflating: /input/dataset5/E/u/depth_20_0038.png
#   inflating: /input/dataset5/E/u/depth_20_0039.png
#   inflating: /input/dataset5/E/u/depth_20_0040.png
#   inflating: /input/dataset5/E/u/depth_20_0041.png
#   inflating: /input/dataset5/E/u/depth_20_0042.png
#   inflating: /input/dataset5/E/u/depth_20_0043.png
#   inflating: /input/dataset5/E/u/depth_20_0044.png
#   inflating: /input/dataset5/E/u/depth_20_0045.png
#   inflating: /input/dataset5/E/u/depth_20_0046.png
#   inflating: /input/dataset5/E/u/depth_20_0047.png
#   inflating: /input/dataset5/E/u/depth_20_0048.png
#   inflating: /input/dataset5/E/u/depth_20_0049.png
#   inflating: /input/dataset5/E/u/depth_20_0050.png
#   inflating: /input/dataset5/E/u/depth_20_0051.png
#   inflating: /input/dataset5/E/u/depth_20_0052.png
#   inflating: /input/dataset5/E/u/depth_20_0053.png
#   inflating: /input/dataset5/E/u/depth_20_0054.png
#   inflating: /input/dataset5/E/u/depth_20_0055.png
#   inflating: /input/dataset5/E/u/depth_20_0056.png
#   inflating: /input/dataset5/E/u/depth_20_0057.png
#   inflating: /input/dataset5/E/u/depth_20_0058.png
#   inflating: /input/dataset5/E/u/depth_20_0059.png
#   inflating: /input/dataset5/E/u/depth_20_0060.png
#   inflating: /input/dataset5/E/u/depth_20_0061.png
#   inflating: /input/dataset5/E/u/depth_20_0062.png
#   inflating: /input/dataset5/E/u/depth_20_0063.png
#   inflating: /input/dataset5/E/u/depth_20_0064.png
#   inflating: /input/dataset5/E/u/depth_20_0065.png
#   inflating: /input/dataset5/E/u/depth_20_0066.png
#   inflating: /input/dataset5/E/u/depth_20_0067.png
#   inflating: /input/dataset5/E/u/depth_20_0068.png
#   inflating: /input/dataset5/E/u/depth_20_0069.png
#   inflating: /input/dataset5/E/u/depth_20_0070.png
#   inflating: /input/dataset5/E/u/depth_20_0071.png
#   inflating: /input/dataset5/E/u/depth_20_0072.png
#   inflating: /input/dataset5/E/u/depth_20_0073.png
#   inflating: /input/dataset5/E/u/depth_20_0074.png
#   inflating: /input/dataset5/E/u/depth_20_0075.png
#   inflating: /input/dataset5/E/u/depth_20_0076.png
#   inflating: /input/dataset5/E/u/depth_20_0077.png
#   inflating: /input/dataset5/E/u/depth_20_0078.png
#   inflating: /input/dataset5/E/u/depth_20_0079.png
#   inflating: /input/dataset5/E/u/depth_20_0080.png
#   inflating: /input/dataset5/E/u/depth_20_0081.png
#   inflating: /input/dataset5/E/u/depth_20_0082.png
#   inflating: /input/dataset5/E/u/depth_20_0083.png
#   inflating: /input/dataset5/E/u/depth_20_0084.png
#   inflating: /input/dataset5/E/u/depth_20_0085.png
#   inflating: /input/dataset5/E/u/depth_20_0086.png
#   inflating: /input/dataset5/E/u/depth_20_0087.png
#   inflating: /input/dataset5/E/u/depth_20_0088.png
#   inflating: /input/dataset5/E/u/depth_20_0089.png
#   inflating: /input/dataset5/E/u/depth_20_0090.png
#   inflating: /input/dataset5/E/u/depth_20_0091.png
#   inflating: /input/dataset5/E/u/depth_20_0092.png
#   inflating: /input/dataset5/E/u/depth_20_0093.png
#   inflating: /input/dataset5/E/u/depth_20_0094.png
#   inflating: /input/dataset5/E/u/depth_20_0095.png
#   inflating: /input/dataset5/E/u/depth_20_0096.png
#   inflating: /input/dataset5/E/u/depth_20_0097.png
#   inflating: /input/dataset5/E/u/depth_20_0098.png
#   inflating: /input/dataset5/E/u/depth_20_0099.png
#   inflating: /input/dataset5/E/u/depth_20_0100.png
#   inflating: /input/dataset5/E/u/depth_20_0101.png
#   inflating: /input/dataset5/E/u/depth_20_0102.png
#   inflating: /input/dataset5/E/u/depth_20_0103.png
#   inflating: /input/dataset5/E/u/depth_20_0104.png
#   inflating: /input/dataset5/E/u/depth_20_0105.png
#   inflating: /input/dataset5/E/u/depth_20_0106.png
#   inflating: /input/dataset5/E/u/depth_20_0107.png
#   inflating: /input/dataset5/E/u/depth_20_0108.png
#   inflating: /input/dataset5/E/u/depth_20_0109.png
#   inflating: /input/dataset5/E/u/depth_20_0110.png
#   inflating: /input/dataset5/E/u/depth_20_0111.png
#   inflating: /input/dataset5/E/u/depth_20_0112.png
#   inflating: /input/dataset5/E/u/depth_20_0113.png
#   inflating: /input/dataset5/E/u/depth_20_0114.png
#   inflating: /input/dataset5/E/u/depth_20_0115.png
#   inflating: /input/dataset5/E/u/depth_20_0116.png
#   inflating: /input/dataset5/E/u/depth_20_0117.png
#   inflating: /input/dataset5/E/u/depth_20_0118.png
#   inflating: /input/dataset5/E/u/depth_20_0119.png
#   inflating: /input/dataset5/E/u/depth_20_0120.png
#   inflating: /input/dataset5/E/u/depth_20_0121.png
#   inflating: /input/dataset5/E/u/depth_20_0122.png
#   inflating: /input/dataset5/E/u/depth_20_0123.png
#   inflating: /input/dataset5/E/u/depth_20_0124.png
#   inflating: /input/dataset5/E/u/depth_20_0125.png
#   inflating: /input/dataset5/E/u/depth_20_0126.png
#   inflating: /input/dataset5/E/u/depth_20_0127.png
#   inflating: /input/dataset5/E/u/depth_20_0128.png
#   inflating: /input/dataset5/E/u/depth_20_0129.png
#   inflating: /input/dataset5/E/u/depth_20_0130.png
#   inflating: /input/dataset5/E/u/depth_20_0131.png
#   inflating: /input/dataset5/E/u/depth_20_0132.png
#   inflating: /input/dataset5/E/u/depth_20_0133.png
#   inflating: /input/dataset5/E/u/depth_20_0134.png
#   inflating: /input/dataset5/E/u/depth_20_0135.png
#   inflating: /input/dataset5/E/u/depth_20_0136.png
#   inflating: /input/dataset5/E/u/depth_20_0137.png
#   inflating: /input/dataset5/E/u/depth_20_0138.png
#   inflating: /input/dataset5/E/u/depth_20_0139.png
#   inflating: /input/dataset5/E/u/depth_20_0140.png
#   inflating: /input/dataset5/E/u/depth_20_0141.png
#   inflating: /input/dataset5/E/u/depth_20_0142.png
#   inflating: /input/dataset5/E/u/depth_20_0143.png
#   inflating: /input/dataset5/E/u/depth_20_0144.png
#   inflating: /input/dataset5/E/u/depth_20_0145.png
#   inflating: /input/dataset5/E/u/depth_20_0146.png
#   inflating: /input/dataset5/E/u/depth_20_0147.png
#   inflating: /input/dataset5/E/u/depth_20_0148.png
#   inflating: /input/dataset5/E/u/depth_20_0149.png
#   inflating: /input/dataset5/E/u/depth_20_0150.png
#   inflating: /input/dataset5/E/u/depth_20_0151.png
#   inflating: /input/dataset5/E/u/depth_20_0152.png
#   inflating: /input/dataset5/E/u/depth_20_0153.png
#   inflating: /input/dataset5/E/u/depth_20_0154.png
#   inflating: /input/dataset5/E/u/depth_20_0155.png
#   inflating: /input/dataset5/E/u/depth_20_0156.png
#   inflating: /input/dataset5/E/u/depth_20_0157.png
#   inflating: /input/dataset5/E/u/depth_20_0158.png
#   inflating: /input/dataset5/E/u/depth_20_0159.png
#   inflating: /input/dataset5/E/u/depth_20_0160.png
#   inflating: /input/dataset5/E/u/depth_20_0161.png
#   inflating: /input/dataset5/E/u/depth_20_0162.png
#   inflating: /input/dataset5/E/u/depth_20_0163.png
#   inflating: /input/dataset5/E/u/depth_20_0164.png
#   inflating: /input/dataset5/E/u/depth_20_0165.png
#   inflating: /input/dataset5/E/u/depth_20_0166.png
#   inflating: /input/dataset5/E/u/depth_20_0167.png
#   inflating: /input/dataset5/E/u/depth_20_0168.png
#   inflating: /input/dataset5/E/u/depth_20_0169.png
#   inflating: /input/dataset5/E/u/depth_20_0170.png
#   inflating: /input/dataset5/E/u/depth_20_0171.png
#   inflating: /input/dataset5/E/u/depth_20_0172.png
#   inflating: /input/dataset5/E/u/depth_20_0173.png
#   inflating: /input/dataset5/E/u/depth_20_0174.png
#   inflating: /input/dataset5/E/u/depth_20_0175.png
#   inflating: /input/dataset5/E/u/depth_20_0176.png
#   inflating: /input/dataset5/E/u/depth_20_0177.png
#   inflating: /input/dataset5/E/u/depth_20_0178.png
#   inflating: /input/dataset5/E/u/depth_20_0179.png
#   inflating: /input/dataset5/E/u/depth_20_0180.png
#   inflating: /input/dataset5/E/u/depth_20_0181.png
#   inflating: /input/dataset5/E/u/depth_20_0182.png
#   inflating: /input/dataset5/E/u/depth_20_0183.png
#   inflating: /input/dataset5/E/u/depth_20_0184.png
#   inflating: /input/dataset5/E/u/depth_20_0185.png
#   inflating: /input/dataset5/E/u/depth_20_0186.png
#   inflating: /input/dataset5/E/u/depth_20_0187.png
#   inflating: /input/dataset5/E/u/depth_20_0188.png
#   inflating: /input/dataset5/E/u/depth_20_0189.png
#   inflating: /input/dataset5/E/u/depth_20_0190.png
#   inflating: /input/dataset5/E/u/depth_20_0191.png
#   inflating: /input/dataset5/E/u/depth_20_0192.png
#   inflating: /input/dataset5/E/u/depth_20_0193.png
#   inflating: /input/dataset5/E/u/depth_20_0194.png
#   inflating: /input/dataset5/E/u/depth_20_0195.png
#   inflating: /input/dataset5/E/u/depth_20_0196.png
#   inflating: /input/dataset5/E/u/depth_20_0197.png
#   inflating: /input/dataset5/E/u/depth_20_0198.png
#   inflating: /input/dataset5/E/u/depth_20_0199.png
#   inflating: /input/dataset5/E/u/depth_20_0200.png
#   inflating: /input/dataset5/E/u/depth_20_0201.png
#   inflating: /input/dataset5/E/u/depth_20_0202.png
#   inflating: /input/dataset5/E/u/depth_20_0203.png
#   inflating: /input/dataset5/E/u/depth_20_0204.png
#   inflating: /input/dataset5/E/u/depth_20_0205.png
#   inflating: /input/dataset5/E/u/depth_20_0206.png
#   inflating: /input/dataset5/E/u/depth_20_0207.png
#   inflating: /input/dataset5/E/u/depth_20_0208.png
#   inflating: /input/dataset5/E/u/depth_20_0209.png
#   inflating: /input/dataset5/E/u/depth_20_0210.png
#   inflating: /input/dataset5/E/u/depth_20_0211.png
#   inflating: /input/dataset5/E/u/depth_20_0212.png
#   inflating: /input/dataset5/E/u/depth_20_0213.png
#   inflating: /input/dataset5/E/u/depth_20_0214.png
#   inflating: /input/dataset5/E/u/depth_20_0215.png
#   inflating: /input/dataset5/E/u/depth_20_0216.png
#   inflating: /input/dataset5/E/u/depth_20_0217.png
#   inflating: /input/dataset5/E/u/depth_20_0218.png
#   inflating: /input/dataset5/E/u/depth_20_0219.png
#   inflating: /input/dataset5/E/u/depth_20_0220.png
#   inflating: /input/dataset5/E/u/depth_20_0221.png
#   inflating: /input/dataset5/E/u/depth_20_0222.png
#   inflating: /input/dataset5/E/u/depth_20_0223.png
#   inflating: /input/dataset5/E/u/depth_20_0224.png
#   inflating: /input/dataset5/E/u/depth_20_0225.png
#   inflating: /input/dataset5/E/u/depth_20_0226.png
#   inflating: /input/dataset5/E/u/depth_20_0227.png
#   inflating: /input/dataset5/E/u/depth_20_0228.png
#   inflating: /input/dataset5/E/u/depth_20_0229.png
#   inflating: /input/dataset5/E/u/depth_20_0230.png
#   inflating: /input/dataset5/E/u/depth_20_0231.png
#   inflating: /input/dataset5/E/u/depth_20_0232.png
#   inflating: /input/dataset5/E/u/depth_20_0233.png
#   inflating: /input/dataset5/E/u/depth_20_0234.png
#   inflating: /input/dataset5/E/u/depth_20_0235.png
#   inflating: /input/dataset5/E/u/depth_20_0236.png
#   inflating: /input/dataset5/E/u/depth_20_0237.png
#   inflating: /input/dataset5/E/u/depth_20_0238.png
#   inflating: /input/dataset5/E/u/depth_20_0239.png
#   inflating: /input/dataset5/E/u/depth_20_0240.png
#   inflating: /input/dataset5/E/u/depth_20_0241.png
#   inflating: /input/dataset5/E/u/depth_20_0242.png
#   inflating: /input/dataset5/E/u/depth_20_0243.png
#   inflating: /input/dataset5/E/u/depth_20_0244.png
#   inflating: /input/dataset5/E/u/depth_20_0245.png
#   inflating: /input/dataset5/E/u/depth_20_0246.png
#   inflating: /input/dataset5/E/u/depth_20_0247.png
#   inflating: /input/dataset5/E/u/depth_20_0248.png
#   inflating: /input/dataset5/E/u/depth_20_0249.png
#   inflating: /input/dataset5/E/u/depth_20_0250.png
#   inflating: /input/dataset5/E/u/depth_20_0251.png
#   inflating: /input/dataset5/E/u/depth_20_0252.png
#   inflating: /input/dataset5/E/u/depth_20_0253.png
#   inflating: /input/dataset5/E/u/depth_20_0254.png
#   inflating: /input/dataset5/E/u/depth_20_0255.png
#   inflating: /input/dataset5/E/u/depth_20_0256.png
#   inflating: /input/dataset5/E/u/depth_20_0257.png
#   inflating: /input/dataset5/E/u/depth_20_0258.png
#   inflating: /input/dataset5/E/u/depth_20_0259.png
#   inflating: /input/dataset5/E/u/depth_20_0260.png
#   inflating: /input/dataset5/E/u/depth_20_0261.png
#   inflating: /input/dataset5/E/u/depth_20_0262.png
#   inflating: /input/dataset5/E/u/depth_20_0263.png
#   inflating: /input/dataset5/E/u/depth_20_0264.png
#   inflating: /input/dataset5/E/u/depth_20_0265.png
#   inflating: /input/dataset5/E/u/depth_20_0266.png
#   inflating: /input/dataset5/E/u/depth_20_0267.png
#   inflating: /input/dataset5/E/u/depth_20_0268.png
#   inflating: /input/dataset5/E/u/depth_20_0269.png
#   inflating: /input/dataset5/E/u/depth_20_0270.png
#   inflating: /input/dataset5/E/u/depth_20_0271.png
#   inflating: /input/dataset5/E/u/depth_20_0272.png
#   inflating: /input/dataset5/E/u/depth_20_0273.png
#   inflating: /input/dataset5/E/u/depth_20_0274.png
#   inflating: /input/dataset5/E/u/depth_20_0275.png
#   inflating: /input/dataset5/E/u/depth_20_0276.png
#   inflating: /input/dataset5/E/u/depth_20_0277.png
#   inflating: /input/dataset5/E/u/depth_20_0278.png
#   inflating: /input/dataset5/E/u/depth_20_0279.png
#   inflating: /input/dataset5/E/u/depth_20_0280.png
#   inflating: /input/dataset5/E/u/depth_20_0281.png
#   inflating: /input/dataset5/E/u/depth_20_0282.png
#   inflating: /input/dataset5/E/u/depth_20_0283.png
#   inflating: /input/dataset5/E/u/depth_20_0284.png
#   inflating: /input/dataset5/E/u/depth_20_0285.png
#   inflating: /input/dataset5/E/u/depth_20_0286.png
#   inflating: /input/dataset5/E/u/depth_20_0287.png
#   inflating: /input/dataset5/E/u/depth_20_0288.png
#   inflating: /input/dataset5/E/u/depth_20_0289.png
#   inflating: /input/dataset5/E/u/depth_20_0290.png
#   inflating: /input/dataset5/E/u/depth_20_0291.png
#   inflating: /input/dataset5/E/u/depth_20_0292.png
#   inflating: /input/dataset5/E/u/depth_20_0293.png
#   inflating: /input/dataset5/E/u/depth_20_0294.png
#   inflating: /input/dataset5/E/u/depth_20_0295.png
#   inflating: /input/dataset5/E/u/depth_20_0296.png
#   inflating: /input/dataset5/E/u/depth_20_0297.png
#   inflating: /input/dataset5/E/u/depth_20_0298.png
#   inflating: /input/dataset5/E/u/depth_20_0299.png
#   inflating: /input/dataset5/E/u/depth_20_0300.png
#   inflating: /input/dataset5/E/u/depth_20_0301.png
#   inflating: /input/dataset5/E/u/depth_20_0302.png
#   inflating: /input/dataset5/E/u/depth_20_0303.png
#   inflating: /input/dataset5/E/u/depth_20_0304.png
#   inflating: /input/dataset5/E/u/depth_20_0305.png
#   inflating: /input/dataset5/E/u/depth_20_0306.png
#   inflating: /input/dataset5/E/u/depth_20_0307.png
#   inflating: /input/dataset5/E/u/depth_20_0308.png
#   inflating: /input/dataset5/E/u/depth_20_0309.png
#   inflating: /input/dataset5/E/u/depth_20_0310.png
#   inflating: /input/dataset5/E/u/depth_20_0311.png
#   inflating: /input/dataset5/E/u/depth_20_0312.png
#   inflating: /input/dataset5/E/u/depth_20_0313.png
#   inflating: /input/dataset5/E/u/depth_20_0314.png
#   inflating: /input/dataset5/E/u/depth_20_0315.png
#   inflating: /input/dataset5/E/u/depth_20_0316.png
#   inflating: /input/dataset5/E/u/depth_20_0317.png
#   inflating: /input/dataset5/E/u/depth_20_0318.png
#   inflating: /input/dataset5/E/u/depth_20_0319.png
#   inflating: /input/dataset5/E/u/depth_20_0320.png
#   inflating: /input/dataset5/E/u/depth_20_0321.png
#   inflating: /input/dataset5/E/u/depth_20_0322.png
#   inflating: /input/dataset5/E/u/depth_20_0323.png
#   inflating: /input/dataset5/E/u/depth_20_0324.png
#   inflating: /input/dataset5/E/u/depth_20_0325.png
#   inflating: /input/dataset5/E/u/depth_20_0326.png
#   inflating: /input/dataset5/E/u/depth_20_0327.png
#   inflating: /input/dataset5/E/u/depth_20_0328.png
#   inflating: /input/dataset5/E/u/depth_20_0329.png
#   inflating: /input/dataset5/E/u/depth_20_0330.png
#   inflating: /input/dataset5/E/u/depth_20_0331.png
#   inflating: /input/dataset5/E/u/depth_20_0332.png
#   inflating: /input/dataset5/E/u/depth_20_0333.png
#   inflating: /input/dataset5/E/u/depth_20_0334.png
#   inflating: /input/dataset5/E/u/depth_20_0335.png
#   inflating: /input/dataset5/E/u/depth_20_0336.png
#   inflating: /input/dataset5/E/u/depth_20_0337.png
#   inflating: /input/dataset5/E/u/depth_20_0338.png
#   inflating: /input/dataset5/E/u/depth_20_0339.png
#   inflating: /input/dataset5/E/u/depth_20_0340.png
#   inflating: /input/dataset5/E/u/depth_20_0341.png
#   inflating: /input/dataset5/E/u/depth_20_0342.png
#   inflating: /input/dataset5/E/u/depth_20_0343.png
#   inflating: /input/dataset5/E/u/depth_20_0344.png
#   inflating: /input/dataset5/E/u/depth_20_0345.png
#   inflating: /input/dataset5/E/u/depth_20_0346.png
#   inflating: /input/dataset5/E/u/depth_20_0347.png
#   inflating: /input/dataset5/E/u/depth_20_0348.png
#   inflating: /input/dataset5/E/u/depth_20_0349.png
#   inflating: /input/dataset5/E/u/depth_20_0350.png
#   inflating: /input/dataset5/E/u/depth_20_0351.png
#   inflating: /input/dataset5/E/u/depth_20_0352.png
#   inflating: /input/dataset5/E/u/depth_20_0353.png
#   inflating: /input/dataset5/E/u/depth_20_0354.png
#   inflating: /input/dataset5/E/u/depth_20_0355.png
#   inflating: /input/dataset5/E/u/depth_20_0356.png
#   inflating: /input/dataset5/E/u/depth_20_0357.png
#   inflating: /input/dataset5/E/u/depth_20_0358.png
#   inflating: /input/dataset5/E/u/depth_20_0359.png
#   inflating: /input/dataset5/E/u/depth_20_0360.png
#   inflating: /input/dataset5/E/u/depth_20_0361.png
#   inflating: /input/dataset5/E/u/depth_20_0362.png
#   inflating: /input/dataset5/E/u/depth_20_0363.png
#   inflating: /input/dataset5/E/u/depth_20_0364.png
#   inflating: /input/dataset5/E/u/depth_20_0365.png
#   inflating: /input/dataset5/E/u/depth_20_0366.png
#   inflating: /input/dataset5/E/u/depth_20_0367.png
#   inflating: /input/dataset5/E/u/depth_20_0368.png
#   inflating: /input/dataset5/E/u/depth_20_0369.png
#   inflating: /input/dataset5/E/u/depth_20_0370.png
#   inflating: /input/dataset5/E/u/depth_20_0371.png
#   inflating: /input/dataset5/E/u/depth_20_0372.png
#   inflating: /input/dataset5/E/u/depth_20_0373.png
#   inflating: /input/dataset5/E/u/depth_20_0374.png
#   inflating: /input/dataset5/E/u/depth_20_0375.png
#   inflating: /input/dataset5/E/u/depth_20_0376.png
#   inflating: /input/dataset5/E/u/depth_20_0377.png
#   inflating: /input/dataset5/E/u/depth_20_0378.png
#   inflating: /input/dataset5/E/u/depth_20_0379.png
#   inflating: /input/dataset5/E/u/depth_20_0380.png
#   inflating: /input/dataset5/E/u/depth_20_0381.png
#   inflating: /input/dataset5/E/u/depth_20_0382.png
#   inflating: /input/dataset5/E/u/depth_20_0383.png
#   inflating: /input/dataset5/E/u/depth_20_0384.png
#   inflating: /input/dataset5/E/u/depth_20_0385.png
#   inflating: /input/dataset5/E/u/depth_20_0386.png
#   inflating: /input/dataset5/E/u/depth_20_0387.png
#   inflating: /input/dataset5/E/u/depth_20_0388.png
#   inflating: /input/dataset5/E/u/depth_20_0389.png
#   inflating: /input/dataset5/E/u/depth_20_0390.png
#   inflating: /input/dataset5/E/u/depth_20_0391.png
#   inflating: /input/dataset5/E/u/depth_20_0392.png
#   inflating: /input/dataset5/E/u/depth_20_0393.png
#   inflating: /input/dataset5/E/u/depth_20_0394.png
#   inflating: /input/dataset5/E/u/depth_20_0395.png
#   inflating: /input/dataset5/E/u/depth_20_0396.png
#   inflating: /input/dataset5/E/u/depth_20_0397.png
#   inflating: /input/dataset5/E/u/depth_20_0398.png
#   inflating: /input/dataset5/E/u/depth_20_0399.png
#   inflating: /input/dataset5/E/u/depth_20_0400.png
#   inflating: /input/dataset5/E/u/depth_20_0401.png
#   inflating: /input/dataset5/E/u/depth_20_0402.png
#   inflating: /input/dataset5/E/u/depth_20_0403.png
#   inflating: /input/dataset5/E/u/depth_20_0404.png
#   inflating: /input/dataset5/E/u/depth_20_0405.png
#   inflating: /input/dataset5/E/u/depth_20_0406.png
#   inflating: /input/dataset5/E/u/depth_20_0407.png
#   inflating: /input/dataset5/E/u/depth_20_0408.png
#   inflating: /input/dataset5/E/u/depth_20_0409.png
#   inflating: /input/dataset5/E/u/depth_20_0410.png
#   inflating: /input/dataset5/E/u/depth_20_0411.png
#   inflating: /input/dataset5/E/u/depth_20_0412.png
#   inflating: /input/dataset5/E/u/depth_20_0413.png
#   inflating: /input/dataset5/E/u/depth_20_0414.png
#   inflating: /input/dataset5/E/u/depth_20_0415.png
#   inflating: /input/dataset5/E/u/depth_20_0416.png
#   inflating: /input/dataset5/E/u/depth_20_0417.png
#   inflating: /input/dataset5/E/u/depth_20_0418.png
#   inflating: /input/dataset5/E/u/depth_20_0419.png
#   inflating: /input/dataset5/E/u/depth_20_0420.png
#   inflating: /input/dataset5/E/u/depth_20_0421.png
#   inflating: /input/dataset5/E/u/depth_20_0422.png
#   inflating: /input/dataset5/E/u/depth_20_0423.png
#   inflating: /input/dataset5/E/u/depth_20_0424.png
#   inflating: /input/dataset5/E/u/depth_20_0425.png
#   inflating: /input/dataset5/E/u/depth_20_0426.png
#   inflating: /input/dataset5/E/u/depth_20_0427.png
#   inflating: /input/dataset5/E/u/depth_20_0428.png
#   inflating: /input/dataset5/E/u/depth_20_0429.png
#   inflating: /input/dataset5/E/u/depth_20_0430.png
#   inflating: /input/dataset5/E/u/depth_20_0431.png
#   inflating: /input/dataset5/E/u/depth_20_0432.png
#   inflating: /input/dataset5/E/u/depth_20_0433.png
#   inflating: /input/dataset5/E/u/depth_20_0434.png
#   inflating: /input/dataset5/E/u/depth_20_0435.png
#   inflating: /input/dataset5/E/u/depth_20_0436.png
#   inflating: /input/dataset5/E/u/depth_20_0437.png
#   inflating: /input/dataset5/E/u/depth_20_0438.png
#   inflating: /input/dataset5/E/u/depth_20_0439.png
#   inflating: /input/dataset5/E/u/depth_20_0440.png
#   inflating: /input/dataset5/E/u/depth_20_0441.png
#   inflating: /input/dataset5/E/u/depth_20_0442.png
#   inflating: /input/dataset5/E/u/depth_20_0443.png
#   inflating: /input/dataset5/E/u/depth_20_0444.png
#   inflating: /input/dataset5/E/u/depth_20_0445.png
#   inflating: /input/dataset5/E/u/depth_20_0446.png
#   inflating: /input/dataset5/E/u/depth_20_0447.png
#   inflating: /input/dataset5/E/u/depth_20_0448.png
#   inflating: /input/dataset5/E/u/depth_20_0449.png
#   inflating: /input/dataset5/E/u/depth_20_0450.png
#   inflating: /input/dataset5/E/u/depth_20_0451.png
#   inflating: /input/dataset5/E/u/depth_20_0452.png
#   inflating: /input/dataset5/E/u/depth_20_0453.png
#   inflating: /input/dataset5/E/u/depth_20_0454.png
#   inflating: /input/dataset5/E/u/depth_20_0455.png
#   inflating: /input/dataset5/E/u/depth_20_0456.png
#   inflating: /input/dataset5/E/u/depth_20_0457.png
#   inflating: /input/dataset5/E/u/depth_20_0458.png
#   inflating: /input/dataset5/E/u/depth_20_0459.png
#   inflating: /input/dataset5/E/u/depth_20_0460.png
#   inflating: /input/dataset5/E/u/depth_20_0461.png
#   inflating: /input/dataset5/E/u/depth_20_0462.png
#   inflating: /input/dataset5/E/u/depth_20_0463.png
#   inflating: /input/dataset5/E/u/depth_20_0464.png
#   inflating: /input/dataset5/E/u/depth_20_0465.png
#   inflating: /input/dataset5/E/u/depth_20_0466.png
#   inflating: /input/dataset5/E/u/depth_20_0467.png
#   inflating: /input/dataset5/E/u/depth_20_0468.png
#   inflating: /input/dataset5/E/u/depth_20_0469.png
#   inflating: /input/dataset5/E/u/depth_20_0470.png
#   inflating: /input/dataset5/E/u/depth_20_0471.png
#   inflating: /input/dataset5/E/u/depth_20_0472.png
#   inflating: /input/dataset5/E/u/depth_20_0473.png
#   inflating: /input/dataset5/E/u/depth_20_0474.png
#   inflating: /input/dataset5/E/u/depth_20_0475.png
#   inflating: /input/dataset5/E/u/depth_20_0476.png
#   inflating: /input/dataset5/E/u/depth_20_0477.png
#   inflating: /input/dataset5/E/u/depth_20_0478.png
#   inflating: /input/dataset5/E/u/depth_20_0479.png
#   inflating: /input/dataset5/E/u/depth_20_0480.png
#   inflating: /input/dataset5/E/u/depth_20_0481.png
#   inflating: /input/dataset5/E/u/depth_20_0482.png
#   inflating: /input/dataset5/E/u/depth_20_0483.png
#   inflating: /input/dataset5/E/u/depth_20_0484.png
#   inflating: /input/dataset5/E/u/depth_20_0485.png
#   inflating: /input/dataset5/E/u/depth_20_0486.png
#   inflating: /input/dataset5/E/u/depth_20_0487.png
#   inflating: /input/dataset5/E/u/depth_20_0488.png
#   inflating: /input/dataset5/E/u/depth_20_0489.png
#   inflating: /input/dataset5/E/u/depth_20_0490.png
#   inflating: /input/dataset5/E/u/depth_20_0491.png
#   inflating: /input/dataset5/E/u/depth_20_0492.png
#   inflating: /input/dataset5/E/u/depth_20_0493.png
#   inflating: /input/dataset5/E/u/depth_20_0494.png
#   inflating: /input/dataset5/E/u/depth_20_0495.png
#   inflating: /input/dataset5/E/u/depth_20_0496.png
#   inflating: /input/dataset5/E/u/depth_20_0497.png
#   inflating: /input/dataset5/E/u/depth_20_0498.png
#   inflating: /input/dataset5/E/u/depth_20_0499.png
#   inflating: /input/dataset5/E/u/depth_20_0500.png
#   inflating: /input/dataset5/E/u/depth_20_0501.png
#   inflating: /input/dataset5/E/u/depth_20_0502.png
#   inflating: /input/dataset5/E/u/depth_20_0503.png
#   inflating: /input/dataset5/E/u/depth_20_0504.png
#   inflating: /input/dataset5/E/u/depth_20_0505.png
#   inflating: /input/dataset5/E/u/depth_20_0506.png
#   inflating: /input/dataset5/E/u/depth_20_0507.png
#   inflating: /input/dataset5/E/u/depth_20_0508.png
#   inflating: /input/dataset5/E/u/depth_20_0509.png
#   inflating: /input/dataset5/E/u/depth_20_0510.png
#   inflating: /input/dataset5/E/u/depth_20_0511.png
#   inflating: /input/dataset5/E/u/depth_20_0512.png
#   inflating: /input/dataset5/E/u/depth_20_0513.png
#   inflating: /input/dataset5/E/u/depth_20_0514.png
#   inflating: /input/dataset5/E/u/depth_20_0515.png
#   inflating: /input/dataset5/E/u/depth_20_0516.png
#   inflating: /input/dataset5/E/u/depth_20_0517.png
#   inflating: /input/dataset5/E/u/depth_20_0518.png
#   inflating: /input/dataset5/E/u/depth_20_0519.png
#   inflating: /input/dataset5/E/u/depth_20_0520.png
#   inflating: /input/dataset5/E/u/depth_20_0521.png
#   inflating: /input/dataset5/E/u/depth_20_0522.png
#   inflating: /input/dataset5/E/u/depth_20_0523.png
#   inflating: /input/dataset5/E/u/depth_20_0524.png
#   inflating: /input/dataset5/E/u/depth_20_0525.png
#   inflating: /input/dataset5/E/u/depth_20_0526.png
#   inflating: /input/dataset5/E/u/depth_20_0527.png
#   inflating: /input/dataset5/E/u/depth_20_0528.png
#   inflating: /input/dataset5/E/u/depth_20_0529.png
#   inflating: /input/dataset5/E/u/depth_20_0530.png
#   inflating: /input/dataset5/E/v/color_21_0002.png
#   inflating: /input/dataset5/E/v/color_21_0003.png
#   inflating: /input/dataset5/E/v/color_21_0004.png
#   inflating: /input/dataset5/E/v/color_21_0005.png
#   inflating: /input/dataset5/E/v/color_21_0006.png
#   inflating: /input/dataset5/E/v/color_21_0007.png
#   inflating: /input/dataset5/E/v/color_21_0008.png
#   inflating: /input/dataset5/E/v/color_21_0009.png
#   inflating: /input/dataset5/E/v/color_21_0010.png
#   inflating: /input/dataset5/E/v/color_21_0011.png
#   inflating: /input/dataset5/E/v/color_21_0012.png
#   inflating: /input/dataset5/E/v/color_21_0013.png
#   inflating: /input/dataset5/E/v/color_21_0014.png
#   inflating: /input/dataset5/E/v/color_21_0015.png
#   inflating: /input/dataset5/E/v/color_21_0016.png
#   inflating: /input/dataset5/E/v/color_21_0017.png
#   inflating: /input/dataset5/E/v/color_21_0018.png
#   inflating: /input/dataset5/E/v/color_21_0019.png
#   inflating: /input/dataset5/E/v/color_21_0020.png
#   inflating: /input/dataset5/E/v/color_21_0021.png
#   inflating: /input/dataset5/E/v/color_21_0022.png
#   inflating: /input/dataset5/E/v/color_21_0023.png
#   inflating: /input/dataset5/E/v/color_21_0024.png
#   inflating: /input/dataset5/E/v/color_21_0025.png
#   inflating: /input/dataset5/E/v/color_21_0026.png
#   inflating: /input/dataset5/E/v/color_21_0027.png
#   inflating: /input/dataset5/E/v/color_21_0028.png
#   inflating: /input/dataset5/E/v/color_21_0029.png
#   inflating: /input/dataset5/E/v/color_21_0030.png
#   inflating: /input/dataset5/E/v/color_21_0031.png
#   inflating: /input/dataset5/E/v/color_21_0032.png
#   inflating: /input/dataset5/E/v/color_21_0033.png
#   inflating: /input/dataset5/E/v/color_21_0034.png
#   inflating: /input/dataset5/E/v/color_21_0035.png
#   inflating: /input/dataset5/E/v/color_21_0036.png
#   inflating: /input/dataset5/E/v/color_21_0037.png
#   inflating: /input/dataset5/E/v/color_21_0038.png
#   inflating: /input/dataset5/E/v/color_21_0039.png
#   inflating: /input/dataset5/E/v/color_21_0040.png
#   inflating: /input/dataset5/E/v/color_21_0041.png
#   inflating: /input/dataset5/E/v/color_21_0042.png
#   inflating: /input/dataset5/E/v/color_21_0043.png
#   inflating: /input/dataset5/E/v/color_21_0044.png
#   inflating: /input/dataset5/E/v/color_21_0045.png
#   inflating: /input/dataset5/E/v/color_21_0046.png
#   inflating: /input/dataset5/E/v/color_21_0047.png
#   inflating: /input/dataset5/E/v/color_21_0048.png
#   inflating: /input/dataset5/E/v/color_21_0049.png
#   inflating: /input/dataset5/E/v/color_21_0050.png
#   inflating: /input/dataset5/E/v/color_21_0051.png
#   inflating: /input/dataset5/E/v/color_21_0052.png
#   inflating: /input/dataset5/E/v/color_21_0053.png
#   inflating: /input/dataset5/E/v/color_21_0054.png
#   inflating: /input/dataset5/E/v/color_21_0055.png
#   inflating: /input/dataset5/E/v/color_21_0056.png
#   inflating: /input/dataset5/E/v/color_21_0057.png
#   inflating: /input/dataset5/E/v/color_21_0058.png
#   inflating: /input/dataset5/E/v/color_21_0059.png
#   inflating: /input/dataset5/E/v/color_21_0060.png
#   inflating: /input/dataset5/E/v/color_21_0061.png
#   inflating: /input/dataset5/E/v/color_21_0062.png
#   inflating: /input/dataset5/E/v/color_21_0063.png
#   inflating: /input/dataset5/E/v/color_21_0064.png
#   inflating: /input/dataset5/E/v/color_21_0065.png
#   inflating: /input/dataset5/E/v/color_21_0066.png
#   inflating: /input/dataset5/E/v/color_21_0067.png
#   inflating: /input/dataset5/E/v/color_21_0068.png
#   inflating: /input/dataset5/E/v/color_21_0069.png
#   inflating: /input/dataset5/E/v/color_21_0070.png
#   inflating: /input/dataset5/E/v/color_21_0071.png
#   inflating: /input/dataset5/E/v/color_21_0072.png
#   inflating: /input/dataset5/E/v/color_21_0073.png
#   inflating: /input/dataset5/E/v/color_21_0074.png
#   inflating: /input/dataset5/E/v/color_21_0075.png
#   inflating: /input/dataset5/E/v/color_21_0076.png
#   inflating: /input/dataset5/E/v/color_21_0077.png
#   inflating: /input/dataset5/E/v/color_21_0078.png
#   inflating: /input/dataset5/E/v/color_21_0079.png
#   inflating: /input/dataset5/E/v/color_21_0080.png
# ...
#   inflating: /input/dataset5/E/y/depth_24_0226.png
#   inflating: /input/dataset5/E/y/depth_24_0227.png
#   inflating: /input/dataset5/E/y/depth_24_0228.png
#   inflating: /input/dataset5/E/y/depth_24_0229.png
#   inflating: /input/dataset5/E/y/depth_24_0230.png
#   inflating: /input/dataset5/E/y/depth_24_0231.png
#   inflating: /input/dataset5/E/y/depth_24_0232.png
#   inflating: /input/dataset5/E/y/depth_24_0233.png
#   inflating: /input/dataset5/E/y/depth_24_0234.png
#   inflating: /input/dataset5/E/y/depth_24_0235.png
#   inflating: /input/dataset5/E/y/depth_24_0236.png
#   inflating: /input/dataset5/E/y/depth_24_0237.png
#   inflating: /input/dataset5/E/y/depth_24_0238.png
#   inflating: /input/dataset5/E/y/depth_24_0239.png
#   inflating: /input/dataset5/E/y/depth_24_0240.png
#   inflating: /input/dataset5/E/y/depth_24_0241.png
#   inflating: /input/dataset5/E/y/depth_24_0242.png
#   inflating: /input/dataset5/E/y/depth_24_0243.png
#   inflating: /input/dataset5/E/y/depth_24_0244.png
#   inflating: /input/dataset5/E/y/depth_24_0245.png
#   inflating: /input/dataset5/E/y/depth_24_0246.png
#   inflating: /input/dataset5/E/y/depth_24_0247.png
#   inflating: /input/dataset5/E/y/depth_24_0248.png
#   inflating: /input/dataset5/E/y/depth_24_0249.png
#   inflating: /input/dataset5/E/y/depth_24_0250.png
#   inflating: /input/dataset5/E/y/depth_24_0251.png
#   inflating: /input/dataset5/E/y/depth_24_0252.png
#   inflating: /input/dataset5/E/y/depth_24_0253.png
#   inflating: /input/dataset5/E/y/depth_24_0254.png
#   inflating: /input/dataset5/E/y/depth_24_0255.png
#   inflating: /input/dataset5/E/y/depth_24_0256.png
#   inflating: /input/dataset5/E/y/depth_24_0257.png
#   inflating: /input/dataset5/E/y/depth_24_0258.png
#   inflating: /input/dataset5/E/y/depth_24_0259.png
#   inflating: /input/dataset5/E/y/depth_24_0260.png
#   inflating: /input/dataset5/E/y/depth_24_0261.png
#   inflating: /input/dataset5/E/y/depth_24_0262.png
#   inflating: /input/dataset5/E/y/depth_24_0263.png
#   inflating: /input/dataset5/E/y/depth_24_0264.png
#   inflating: /input/dataset5/E/y/depth_24_0265.png
#   inflating: /input/dataset5/E/y/depth_24_0266.png
#   inflating: /input/dataset5/E/y/depth_24_0267.png
#   inflating: /input/dataset5/E/y/depth_24_0268.png
#   inflating: /input/dataset5/E/y/depth_24_0269.png
#   inflating: /input/dataset5/E/y/depth_24_0270.png
#   inflating: /input/dataset5/E/y/depth_24_0271.png
#   inflating: /input/dataset5/E/y/depth_24_0272.png
#   inflating: /input/dataset5/E/y/depth_24_0273.png
#   inflating: /input/dataset5/E/y/depth_24_0274.png
#   inflating: /input/dataset5/E/y/depth_24_0275.png
#   inflating: /input/dataset5/E/y/depth_24_0276.png
#   inflating: /input/dataset5/E/y/depth_24_0277.png
#   inflating: /input/dataset5/E/y/depth_24_0278.png
#   inflating: /input/dataset5/E/y/depth_24_0279.png
#   inflating: /input/dataset5/E/y/depth_24_0280.png
#   inflating: /input/dataset5/E/y/depth_24_0281.png
#   inflating: /input/dataset5/E/y/depth_24_0282.png
#   inflating: /input/dataset5/E/y/depth_24_0283.png
#   inflating: /input/dataset5/E/y/depth_24_0284.png
#   inflating: /input/dataset5/E/y/depth_24_0285.png
#   inflating: /input/dataset5/E/y/depth_24_0286.png
#   inflating: /input/dataset5/E/y/depth_24_0287.png
#   inflating: /input/dataset5/E/y/depth_24_0288.png
#   inflating: /input/dataset5/E/y/depth_24_0289.png
#   inflating: /input/dataset5/E/y/depth_24_0290.png
#   inflating: /input/dataset5/E/y/depth_24_0291.png
#   inflating: /input/dataset5/E/y/depth_24_0292.png
#   inflating: /input/dataset5/E/y/depth_24_0293.png
#   inflating: /input/dataset5/E/y/depth_24_0294.png
#   inflating: /input/dataset5/E/y/depth_24_0295.png
#   inflating: /input/dataset5/E/y/depth_24_0296.png
#   inflating: /input/dataset5/E/y/depth_24_0297.png
#   inflating: /input/dataset5/E/y/depth_24_0298.png
#   inflating: /input/dataset5/E/y/depth_24_0299.png
#   inflating: /input/dataset5/E/y/depth_24_0300.png
#   inflating: /input/dataset5/E/y/depth_24_0301.png
#   inflating: /input/dataset5/E/y/depth_24_0302.png
#   inflating: /input/dataset5/E/y/depth_24_0303.png
#   inflating: /input/dataset5/E/y/depth_24_0304.png
#   inflating: /input/dataset5/E/y/depth_24_0305.png
#   inflating: /input/dataset5/E/y/depth_24_0306.png
#   inflating: /input/dataset5/E/y/depth_24_0307.png
#   inflating: /input/dataset5/E/y/depth_24_0308.png
#   inflating: /input/dataset5/E/y/depth_24_0309.png
#   inflating: /input/dataset5/E/y/depth_24_0310.png
#   inflating: /input/dataset5/E/y/depth_24_0311.png
#   inflating: /input/dataset5/E/y/depth_24_0312.png
#   inflating: /input/dataset5/E/y/depth_24_0313.png
#   inflating: /input/dataset5/E/y/depth_24_0314.png
#   inflating: /input/dataset5/E/y/depth_24_0315.png
#   inflating: /input/dataset5/E/y/depth_24_0316.png
#   inflating: /input/dataset5/E/y/depth_24_0317.png
#   inflating: /input/dataset5/E/y/depth_24_0318.png
#   inflating: /input/dataset5/E/y/depth_24_0319.png
#   inflating: /input/dataset5/E/y/depth_24_0320.png
#   inflating: /input/dataset5/E/y/depth_24_0321.png
#   inflating: /input/dataset5/E/y/depth_24_0322.png
#   inflating: /input/dataset5/E/y/depth_24_0323.png
#   inflating: /input/dataset5/E/y/depth_24_0324.png
#   inflating: /input/dataset5/E/y/depth_24_0325.png
#   inflating: /input/dataset5/E/y/depth_24_0326.png
#   inflating: /input/dataset5/E/y/depth_24_0327.png
#   inflating: /input/dataset5/E/y/depth_24_0328.png
#   inflating: /input/dataset5/E/y/depth_24_0329.png
#   inflating: /input/dataset5/E/y/depth_24_0330.png
#   inflating: /input/dataset5/E/y/depth_24_0331.png
#   inflating: /input/dataset5/E/y/depth_24_0332.png
#   inflating: /input/dataset5/E/y/depth_24_0333.png
#   inflating: /input/dataset5/E/y/depth_24_0334.png
#   inflating: /input/dataset5/E/y/depth_24_0335.png
#   inflating: /input/dataset5/E/y/depth_24_0336.png
#   inflating: /input/dataset5/E/y/depth_24_0337.png
#   inflating: /input/dataset5/E/y/depth_24_0338.png
#   inflating: /input/dataset5/E/y/depth_24_0339.png
#   inflating: /input/dataset5/E/y/depth_24_0340.png
#   inflating: /input/dataset5/E/y/depth_24_0341.png
#   inflating: /input/dataset5/E/y/depth_24_0342.png
#   inflating: /input/dataset5/E/y/depth_24_0343.png
#   inflating: /input/dataset5/E/y/depth_24_0344.png
#   inflating: /input/dataset5/E/y/depth_24_0345.png
#   inflating: /input/dataset5/E/y/depth_24_0346.png
#   inflating: /input/dataset5/E/y/depth_24_0347.png
#   inflating: /input/dataset5/E/y/depth_24_0348.png
#   inflating: /input/dataset5/E/y/depth_24_0349.png
#   inflating: /input/dataset5/E/y/depth_24_0350.png
#   inflating: /input/dataset5/E/y/depth_24_0351.png
#   inflating: /input/dataset5/E/y/depth_24_0352.png
#   inflating: /input/dataset5/E/y/depth_24_0353.png
#   inflating: /input/dataset5/E/y/depth_24_0354.png
#   inflating: /input/dataset5/E/y/depth_24_0355.png
#   inflating: /input/dataset5/E/y/depth_24_0356.png
#   inflating: /input/dataset5/E/y/depth_24_0357.png
#   inflating: /input/dataset5/E/y/depth_24_0358.png
#   inflating: /input/dataset5/E/y/depth_24_0359.png
#   inflating: /input/dataset5/E/y/depth_24_0360.png
#   inflating: /input/dataset5/E/y/depth_24_0361.png
#   inflating: /input/dataset5/E/y/depth_24_0362.png
#   inflating: /input/dataset5/E/y/depth_24_0363.png
#   inflating: /input/dataset5/E/y/depth_24_0364.png
#   inflating: /input/dataset5/E/y/depth_24_0365.png
#   inflating: /input/dataset5/E/y/depth_24_0366.png
#   inflating: /input/dataset5/E/y/depth_24_0367.png
#   inflating: /input/dataset5/E/y/depth_24_0368.png
#   inflating: /input/dataset5/E/y/depth_24_0369.png
#   inflating: /input/dataset5/E/y/depth_24_0370.png
#   inflating: /input/dataset5/E/y/depth_24_0371.png
#   inflating: /input/dataset5/E/y/depth_24_0372.png
#   inflating: /input/dataset5/E/y/depth_24_0373.png
#   inflating: /input/dataset5/E/y/depth_24_0374.png
#   inflating: /input/dataset5/E/y/depth_24_0375.png
#   inflating: /input/dataset5/E/y/depth_24_0376.png
#   inflating: /input/dataset5/E/y/depth_24_0377.png
#   inflating: /input/dataset5/E/y/depth_24_0378.png
#   inflating: /input/dataset5/E/y/depth_24_0379.png
#   inflating: /input/dataset5/E/y/depth_24_0380.png
#   inflating: /input/dataset5/E/y/depth_24_0381.png
#   inflating: /input/dataset5/E/y/depth_24_0382.png
#   inflating: /input/dataset5/E/y/depth_24_0383.png
#   inflating: /input/dataset5/E/y/depth_24_0384.png
#   inflating: /input/dataset5/E/y/depth_24_0385.png
#   inflating: /input/dataset5/E/y/depth_24_0386.png
#   inflating: /input/dataset5/E/y/depth_24_0387.png
#   inflating: /input/dataset5/E/y/depth_24_0388.png
#   inflating: /input/dataset5/E/y/depth_24_0389.png
#   inflating: /input/dataset5/E/y/depth_24_0390.png
#   inflating: /input/dataset5/E/y/depth_24_0391.png
#   inflating: /input/dataset5/E/y/depth_24_0392.png
#   inflating: /input/dataset5/E/y/depth_24_0393.png
#   inflating: /input/dataset5/E/y/depth_24_0394.png
#   inflating: /input/dataset5/E/y/depth_24_0395.png
#   inflating: /input/dataset5/E/y/depth_24_0396.png
#   inflating: /input/dataset5/E/y/depth_24_0397.png
#   inflating: /input/dataset5/E/y/depth_24_0398.png
#   inflating: /input/dataset5/E/y/depth_24_0399.png
#   inflating: /input/dataset5/E/y/depth_24_0400.png
#   inflating: /input/dataset5/E/y/depth_24_0401.png
#   inflating: /input/dataset5/E/y/depth_24_0402.png
#   inflating: /input/dataset5/E/y/depth_24_0403.png
#   inflating: /input/dataset5/E/y/depth_24_0404.png
#   inflating: /input/dataset5/E/y/depth_24_0405.png
#   inflating: /input/dataset5/E/y/depth_24_0406.png
#   inflating: /input/dataset5/E/y/depth_24_0407.png
#   inflating: /input/dataset5/E/y/depth_24_0408.png
#   inflating: /input/dataset5/E/y/depth_24_0409.png
#   inflating: /input/dataset5/E/y/depth_24_0410.png
#   inflating: /input/dataset5/E/y/depth_24_0411.png
#   inflating: /input/dataset5/E/y/depth_24_0412.png
#   inflating: /input/dataset5/E/y/depth_24_0413.png
#   inflating: /input/dataset5/E/y/depth_24_0414.png
#   inflating: /input/dataset5/E/y/depth_24_0415.png
#   inflating: /input/dataset5/E/y/depth_24_0416.png
#   inflating: /input/dataset5/E/y/depth_24_0417.png
#   inflating: /input/dataset5/E/y/depth_24_0418.png
#   inflating: /input/dataset5/E/y/depth_24_0419.png
#   inflating: /input/dataset5/E/y/depth_24_0420.png
#   inflating: /input/dataset5/E/y/depth_24_0421.png
#   inflating: /input/dataset5/E/y/depth_24_0422.png
#   inflating: /input/dataset5/E/y/depth_24_0423.png
#   inflating: /input/dataset5/E/y/depth_24_0424.png
#   inflating: /input/dataset5/E/y/depth_24_0425.png
#   inflating: /input/dataset5/E/y/depth_24_0426.png
#   inflating: /input/dataset5/E/y/depth_24_0427.png
#   inflating: /input/dataset5/E/y/depth_24_0428.png
#   inflating: /input/dataset5/E/y/depth_24_0429.png
#   inflating: /input/dataset5/E/y/depth_24_0430.png
#   inflating: /input/dataset5/E/y/depth_24_0431.png
#   inflating: /input/dataset5/E/y/depth_24_0432.png
#   inflating: /input/dataset5/E/y/depth_24_0433.png
#   inflating: /input/dataset5/E/y/depth_24_0434.png
#   inflating: /input/dataset5/E/y/depth_24_0435.png
#   inflating: /input/dataset5/E/y/depth_24_0436.png
#   inflating: /input/dataset5/E/y/depth_24_0437.png
#   inflating: /input/dataset5/E/y/depth_24_0438.png
#   inflating: /input/dataset5/E/y/depth_24_0439.png
#   inflating: /input/dataset5/E/y/depth_24_0440.png
#   inflating: /input/dataset5/E/y/depth_24_0441.png
#   inflating: /input/dataset5/E/y/depth_24_0442.png
#   inflating: /input/dataset5/E/y/depth_24_0443.png
#   inflating: /input/dataset5/E/y/depth_24_0444.png
#   inflating: /input/dataset5/E/y/depth_24_0445.png
#   inflating: /input/dataset5/E/y/depth_24_0446.png
#   inflating: /input/dataset5/E/y/depth_24_0447.png
#   inflating: /input/dataset5/E/y/depth_24_0448.png
#   inflating: /input/dataset5/E/y/depth_24_0449.png
#   inflating: /input/dataset5/E/y/depth_24_0450.png
#   inflating: /input/dataset5/E/y/depth_24_0451.png
#   inflating: /input/dataset5/E/y/depth_24_0452.png
#   inflating: /input/dataset5/E/y/depth_24_0453.png
#   inflating: /input/dataset5/E/y/depth_24_0454.png
#   inflating: /input/dataset5/E/y/depth_24_0455.png
#   inflating: /input/dataset5/E/y/depth_24_0456.png
#   inflating: /input/dataset5/E/y/depth_24_0457.png
#   inflating: /input/dataset5/E/y/depth_24_0458.png
#   inflating: /input/dataset5/E/y/depth_24_0459.png
#   inflating: /input/dataset5/E/y/depth_24_0460.png
#   inflating: /input/dataset5/E/y/depth_24_0461.png
#   inflating: /input/dataset5/E/y/depth_24_0462.png
#   inflating: /input/dataset5/E/y/depth_24_0463.png
#   inflating: /input/dataset5/E/y/depth_24_0464.png
#   inflating: /input/dataset5/E/y/depth_24_0465.png
#   inflating: /input/dataset5/E/y/depth_24_0466.png
#   inflating: /input/dataset5/E/y/depth_24_0467.png
#   inflating: /input/dataset5/E/y/depth_24_0468.png
#   inflating: /input/dataset5/E/y/depth_24_0469.png
#   inflating: /input/dataset5/E/y/depth_24_0470.png
#   inflating: /input/dataset5/E/y/depth_24_0471.png
#   inflating: /input/dataset5/E/y/depth_24_0472.png
#   inflating: /input/dataset5/E/y/depth_24_0473.png
#   inflating: /input/dataset5/E/y/depth_24_0474.png
#   inflating: /input/dataset5/E/y/depth_24_0475.png
#   inflating: /input/dataset5/E/y/depth_24_0476.png
#   inflating: /input/dataset5/E/y/depth_24_0477.png
#   inflating: /input/dataset5/E/y/depth_24_0478.png
#   inflating: /input/dataset5/E/y/depth_24_0479.png
#   inflating: /input/dataset5/E/y/depth_24_0480.png
#   inflating: /input/dataset5/E/y/depth_24_0481.png
#   inflating: /input/dataset5/E/y/depth_24_0482.png
#   inflating: /input/dataset5/E/y/depth_24_0483.png
#   inflating: /input/dataset5/E/y/depth_24_0484.png
#   inflating: /input/dataset5/E/y/depth_24_0485.png
#   inflating: /input/dataset5/E/y/depth_24_0486.png
#   inflating: /input/dataset5/E/y/depth_24_0487.png
#   inflating: /input/dataset5/E/y/depth_24_0488.png
#   inflating: /input/dataset5/E/y/depth_24_0489.png
#   inflating: /input/dataset5/E/y/depth_24_0490.png
#   inflating: /input/dataset5/E/y/depth_24_0491.png
#   inflating: /input/dataset5/E/y/depth_24_0492.png
#   inflating: /input/dataset5/E/y/depth_24_0493.png
#   inflating: /input/dataset5/E/y/depth_24_0494.png
#   inflating: /input/dataset5/E/y/depth_24_0495.png
#   inflating: /input/dataset5/E/y/depth_24_0496.png
#   inflating: /input/dataset5/E/y/depth_24_0497.png
#   inflating: /input/dataset5/E/y/depth_24_0498.png
#   inflating: /input/dataset5/E/y/depth_24_0499.png
#   inflating: /input/dataset5/E/y/depth_24_0500.png
#   inflating: /input/dataset5/E/y/depth_24_0501.png
#   inflating: /input/dataset5/E/y/depth_24_0502.png
#   inflating: /input/dataset5/E/y/depth_24_0503.png
#   inflating: /input/dataset5/E/y/depth_24_0504.png
#   inflating: /input/dataset5/E/y/depth_24_0505.png
#   inflating: /input/dataset5/E/y/depth_24_0506.png
#   inflating: /input/dataset5/E/y/depth_24_0507.png
#   inflating: /input/dataset5/E/y/depth_24_0508.png
#   inflating: /input/dataset5/E/y/depth_24_0509.png
#   inflating: /input/dataset5/E/y/depth_24_0510.png
#   inflating: /input/dataset5/E/y/depth_24_0511.png
#   inflating: /input/dataset5/E/y/depth_24_0512.png
#   inflating: /input/dataset5/E/y/depth_24_0513.png
#   inflating: /input/dataset5/E/y/depth_24_0514.png
#   inflating: /input/dataset5/E/y/depth_24_0515.png
#   inflating: /input/dataset5/E/y/depth_24_0516.png
#   inflating: /input/dataset5/E/y/depth_24_0517.png
#   inflating: /input/dataset5/E/y/depth_24_0518.png
#   inflating: /input/dataset5/E/y/depth_24_0519.png
#   inflating: /input/dataset5/E/y/depth_24_0520.png
#   inflating: /input/dataset5/E/y/depth_24_0521.png
#   inflating: /input/dataset5/E/y/depth_24_0522.png
# Archive:  /content/vgg19.zip
#   inflating: /input/imagenet_class_index.json
#   inflating: /input/vgg19_weights_tf_dim_ordering_tf_kernels.h5
#   inflating: /input/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5

# %% [markdown]
# # Import Environments

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
# os.mkdir("../input")
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5', 'dataset5', 'vgg19_weights_tf_dim_ordering_tf_kernels.h5', 'imagenet_class_index.json']

# %% [markdown]
# ### Define function to store labels and images into a dictionary

# %%
import glob

def get_labels_images(filepath):
    data_dict = {}
    for directory in glob.glob(filepath):
        images = []
        for file in glob.glob(directory+'/color_*.png'):
            images.append(file)
        data_dict.setdefault(directory[-1], images)
        
    return data_dict

# %%
dataset_dir = os.path.abspath('../input/dataset5/*/*')
data_dict = get_labels_images(dataset_dir)

# %% [markdown]
# ### Display some images for sanity

# %%
import cv2
import matplotlib.pyplot as plt

plt.figure(figsize = (25,20))

for i, (k,v) in enumerate(data_dict.items()):
    img = cv2.imread(v[0])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (64,64))
    plt.subplot(4,6,i+1)
    plt.imshow(img)
    plt.title(k + ":" + os.path.basename(v[0]))
    
plt.show()

# %% [markdown]
# ### Define function to preprocess images

# %%
def preprocess_images(dictionary, height = 64, width = 64):
    images = []
    labels = []
    for k,v in dictionary.items():
        for file in v:
            img = cv2.imread(file)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  #channel
            img = cv2.resize(img, (height, width))  #size
            img = img / 255.  #normalize
            images.append(img)
            labels.append(k)
    
    return (np.array(images), np.array(labels).reshape(-1,1))

images, labels = preprocess_images(data_dict)

# %% [markdown]
# ### Encode our labels

# %%
from sklearn.preprocessing import LabelBinarizer

lbl_binarizer = LabelBinarizer()
labels = lbl_binarizer.fit_transform(labels)

# %% [markdown]
# ### Define function to create train, dev, test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size = 0.2, random_state = 1)
X_train, X_dev, Y_train, Y_dev = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 1)

print('Number of training samples:{}, Shape: {}'.format(len(X_train), X_train.shape))
print('Number of dev samples:{}, Shape: {}'.format(len(X_dev), X_dev.shape))
print('Number of test samples:{}, Shape: {}'.format(len(X_test), X_test.shape))
# Out:
# Number of training samples:8338, Shape: (8338, 64, 64, 3)
# Number of dev samples:2780, Shape: (2780, 64, 64, 3)
# Number of test samples:2780, Shape: (2780, 64, 64, 3)

# %% [markdown]
# ### Display some images for sanity

# %%
plt.figure(figsize = (25,15))

for i in range(5):
    plt.subplot(3,5,i+1)
    plt.imshow(X_train[i])
    plt.title('Train Set: {}'.format(lbl_binarizer.classes_[np.argmax(Y_train[i], axis = -1)]))

for i in range(5,10):
    plt.subplot(3,5,i+1)
    plt.imshow(X_dev[i])
    plt.title('Dev Set: {}'.format(lbl_binarizer.classes_[np.argmax(Y_dev[i], axis = -1)]))

for i in range(10,15):
    plt.subplot(3,5,i+1)
    plt.imshow(X_test[i])
    plt.title('Test Set: {}'.format(lbl_binarizer.classes_[np.argmax(Y_test[i], axis = -1)]))

plt.show()

# %% [markdown]
# ### Build our model

# %%
from tensorflow import keras
from keras import optimizers
from keras.applications.vgg19 import VGG19

optimizer=keras.optimizers.RMSprop(learning_rate=0.01)

img_height = 64
img_width = 64
img_channels = 3
num_classes = labels.shape[1]
learning_rate = 1e-5
weights = '../input/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5'

def build_model():
    base = VGG19(include_top = False, weights = weights, input_shape = (img_height, img_width, img_channels))
    X = base.output
    X = keras.layers.Flatten()(X)
    X = keras.layers.Dense(512, activation = 'relu')(X)
    X = keras.layers.Dropout(0.4)(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.Dense(512, activation = 'relu')(X)
    X = keras.layers.Dropout(0.3)(X)
    X = keras.layers.BatchNormalization()(X)
    preds = keras.layers.Dense(num_classes, activation = 'softmax')(X)
    
    model = keras.models.Model(inputs = base.input, outputs = preds)
    model.compile(optimizer = keras.optimizers.RMSprop(lr = learning_rate), loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 24)                12312
#
# =================================================================
# Total params: 21,352,536
# Trainable params: 21,350,488
# Non-trainable params: 2,048
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# ### Define our callbacks and train our model

# %%
callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 0, restore_best_weights = True)]

history = model.fit(X_train, Y_train,
                    epochs = 25,
                    batch_size = 128,
                    validation_data = (X_dev, Y_dev),
                    callbacks = callbacks)
# Out:
# Epoch 1/25
# 59/59 [==============================] - 1817s 31s/step - loss: 2.6260 - accuracy: 0.2761 - val_loss: 2.3033 - val_accuracy: 0.5988
# Epoch 2/25
# 59/59 [==============================] - 1795s 30s/step - loss: 1.3875 - accuracy: 0.6259 - val_loss: 1.3452 - val_accuracy: 0.8598
# Epoch 3/25
# 59/59 [==============================] - 1786s 30s/step - loss: 0.8294 - accuracy: 0.8056 - val_loss: 0.6108 - val_accuracy: 0.9375
# Epoch 4/25

# %% [markdown]
# ### Plot our metrics

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize = (10, 7))

plt.subplot(1,2,1)
plt.plot(epochs, acc, c = 'b', label = 'Training Accuracy')
plt.plot(epochs, val_acc, c = 'g', label = 'Validation Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, loss, c = 'b', label = 'Training Loss')
plt.plot(epochs, val_loss, c = 'g', label = 'Validation Loss')
plt.title('Training vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Evaluate model on test set

# %%
eval_loss, eval_acc = model.evaluate(X_test, Y_test)
print('Evaluation Loss: {:.4f}, Evaluation Accuracy: {:.2f}'.format(eval_loss, eval_acc * 100))
# Out:
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0032 - accuracy: 0.9993
# Evaluation Loss: 0.0032, Evaluation Accuracy: 99.93

# %% [markdown]
# ### Make predictions

# %%
preds = model.predict(X_test)

plt.figure(figsize = (25,20))
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(X_test[i])
    plt.title('true: {} - pred: {}'.format(lbl_binarizer.classes_[np.argmax(Y_test[i], axis = -1)], lbl_binarizer.classes_[np.argmax(preds[i], axis = -1)]))
    
plt.show()

# %% [markdown]
# ### Test with custom images

# %%
# os.mkdir("/content/img")

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd59d2c0-9d3d-4c9b-a193-82fed690580d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd59d2c0-9d3d-4c9b-a193-82fed690580d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving asl-a-new.jpg to asl-a-new.jpg

# %%
os.mkdir("/content/img")

# %%
import shutil

original = r'/content/asl-a-new-cropped.jpg'
target = r'/content/img'

shutil.move(original, target)
# Out:
# '/content/img/asl-a-new-cropped.jpg'

# %%
# test = files.upload()
# path = list(test.keys())[0]
custom_images_path = "/content/img"

def prepare_custom_images(filepath, height = 64, width = 64):
    images = []
    for file in os.listdir(filepath):
        img = cv2.imread(os.path.join(filepath, file))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (height, width))
        img = img / 255.
        images.append(img)
    
    return np.array(images)

custom_images = prepare_custom_images(custom_images_path)

# %%
custom_preds = model.predict(custom_images)

plt.figure(figsize = (25,20))
for i in range(len(custom_preds)):
    plt.subplot(1,2,i+1)
    plt.imshow(custom_images[i])
    plt.title('pred: {}'.format(lbl_binarizer.classes_[np.argmax(custom_preds[i], axis = -1)]))
    
plt.show()

# %% [markdown]
# ### Save model

# %%
model_path = 'models'
if not os.path.isdir(model_path): os.mkdir(model_path)

model.save('models/asl_model.h5')

# %% [markdown]
# # Convert model to TFLite

# %%
import tensorflow as tf

# %%
ASL_SAVED_MODEL = "saved_models/asl_trial"
tf.saved_model.save(model, ASL_SAVED_MODEL)
# Out:
# INFO:tensorflow:Assets written to: saved_models/asl_trial/assets

# %%
import tensorflow_hub as hub

# %%
ASL_SAVED_MODEL = "models/asl_model.h5"

# %%
asl_model = hub.load(ASL_SAVED_MODEL)
print(asl_model)
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject object at 0x7f88fb9a7510>

# %%
# !mkdir "tflite_models"

TFLITE_MODEL = "tflite_models/asl_trial.tflite"
TFLITE_QUANT_MODEL = "tflite_models/asl_trial-quant.tflite"

# %%
# Get the concrete function from the Keras model.
run_model = tf.function(lambda x : asl_model(x))

# Save the concrete function.
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype)
)

# Convert the model
converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func])
converted_tflite_model = converter.convert()
open(TFLITE_MODEL, "wb").write(converted_tflite_model)

# Convert the model to quantized version with post-training quantization
converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func])
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_quant_model = converter.convert()
open(TFLITE_QUANT_MODEL, "wb").write(tflite_quant_model)

print("TFLite models and their sizes:")
# !ls "tflite_models" -lh
# Out:
# WARNING:absl:Please consider providing the trackable_obj argument in the from_concrete_functions. Providing without the trackable_obj argument is deprecated and it will use the deprecated conversion path.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# WARNING:absl:Please consider providing the trackable_obj argument in the from_concrete_functions. Providing without the trackable_obj argument is deprecated and it will use the deprecated conversion path.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# TFLite models and their sizes:
# total 102M
# -rw-r--r-- 1 root root 21M Jun  9 10:56 asl_trial-quant.tflite
# -rw-r--r-- 1 root root 82M Jun  9 10:56 asl_trial.tflite
